# %%
from gbr import inference

# %% [markdown]
# The model trained on 601.200 samples each consists 8 features
# ---------------------
# - nextFundingRate (Estimated funding rate)
# - rolling_mean_12
# - rolling_std_12
# - rolling_mean_24
# - rolling_std_24
# - previous_realized (Realized rate in the last cycle on Binance)
# - ticks_until_realization (how far is the current sample is from the realization)
# - bb_previous_realized (Realized rate in the last cycle on Bybit)

# %% [markdown]
# #### This is how its perform on a data its been trained on
# Training data:
# - BTCUSDT
# - ETHUSDT
# - ADAUSDT
# - DOTUSDT
# - 1INCHUSDT
# - AAVEUSDT
# - BNBUSDT
# - ENJUSDT
# - DOGEUSDT

# %%
inference("BTCUSDT")
# Out:
# Loading data into the memory...
# Data loaded into the memory
# Prepairing dataset for symbol: [BTCUSDT]
# Dataset ready for symbol: [BTCUSDT]
# (84400, 8)
# 84400

# %%
inference("ETHUSDT")
# Out:
# Loading data into the memory...
# Data loaded into the memory
# Prepairing dataset for symbol: [ETHUSDT]
# Dataset ready for symbol: [ETHUSDT]
# (74800, 8)
# 74800

# %% [markdown]
# #### This is how its perform on a data its never seen before

# %%
inference("MKRUSDT")
# Out:
# Loading data into the memory...
# Data loaded into the memory
# Prepairing dataset for symbol: [MKRUSDT]
# Dataset ready for symbol: [MKRUSDT]
# (32400, 8)
# 32400

# %%
inference("LTCUSDT")
# Out:
# Loading data into the memory...
# Data loaded into the memory
# Prepairing dataset for symbol: [LTCUSDT]
# Dataset ready for symbol: [LTCUSDT]
# (61200, 8)
# 61200
